# %% [markdown]
# # Capstone Project (Assessment Criteria Checklist)
#
# <table>
#   <thead>
#     <tr style="font-size: 1.5rem;">
#       <th>Learning Outcome</th>
#       <th>Description</th>
#       <th>Done</th>
#     </tr>
#   </thead>
#   <tbody>
#     <!-- LO1 -->
#     <tr  style="font-size: 1.2rem;">
#       <td><strong>LO1</strong></td>
#       <td><strong>Apply the core principles and theories of data analytics, including statistics, probability, and basic data analysis techniques.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">1.1</td>
#       <td>Describe statistics, probability, and data analysis principles.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">1.2</td>
#       <td>Illustrate the application of these core principles using relevant examples to demonstrate practical understanding and application.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <!-- LO2 -->
#     <tr style="font-size: 1.2rem;">
#       <td><strong>LO2</strong></td>
#       <td><strong>Apply practical skills in manipulating, analysing, and interpreting data using popular data science tools and the Python programming language.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">2.1</td>
#       <td>Utilise data analytics tools and Python to manipulate and analyse data.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">2.2</td>
#       <td>Evaluate Python code and queries written.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">2.3</td>
#       <td>Implement data analysis techniques, coding, and tool usage.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <!-- LO3 -->
#     <tr style="font-size: 1.2rem;">
#       <td><strong>LO3</strong></td>
#       <td><strong>Analyse real-world problems using data analytics methodologies.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">3.1</td>
#       <td>Conduct analysis by applying data analytics methodologies to a real-world dataset.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">3.2</td>
#       <td>Evaluate the problem-solving approach and solutions proposed.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">3.3</td>
#       <td>Design the approach, analysis, and problem-solving techniques used for your specific data set.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <!-- LO4 -->
#     <tr style="font-size: 1.2rem;">
#       <td><strong>LO4</strong></td>
#       <td><strong>Demonstrate Jupyter Notebook usage for data analysis, enhanced by AI assistant.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">4.1</td>
#       <td>Integrate AI tools in data analysis tasks.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">4.2</td>
#       <td>Apply generative AI solutions in storytelling with data.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">4.3</td>
#       <td>Evaluate the data analysis, including identifying limitations and considering alternative solutions.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <!-- LO5 -->
#     <tr style="font-size: 1.2rem;">
#       <td><strong>LO5</strong></td>
#       <td><strong>Implement effective data management practices, covering data collection, cleaning, storage, and processing.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">5.1</td>
#       <td>Demonstrate the effectiveness of data collection, cleaning, storage, and processing techniques.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">5.2</td>
#       <td>Apply best practices in handling and processing data.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <!-- LO6 -->
#     <tr style="font-size: 1.2rem;">
#       <td><strong>LO6</strong></td>
#       <td><strong>Assess ethical considerations, data privacy, and governance in data analytics practices, understanding the legal and social implications of data handling.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">6.1</td>
#       <td>Examine ethical issues, data privacy, and governance in the project’s methodology.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">6.2</td>
#       <td>Discuss the legal and social implications of the data handling and findings.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <!-- LO7 -->
#     <tr style="font-size: 1.2rem;">
#       <td><strong>LO7</strong></td>
#       <td><strong>Design and outline independent research projects in data analytics, showing an understanding of various research methodologies.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">7.1</td>
#       <td>Organise your project effectively using best practices.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">7.2</td>
#       <td>Select research methodologies applicable to the project goals.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <!-- LO8 -->
#     <tr style="font-size: 1.2rem;">
#       <td><strong>LO8</strong></td>
#       <td><strong>Communicate complex data insights to both technical and non-technical audiences.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">8.1</td>
#       <td>Articulate complex data insights to technical and non-technical audiences.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">8.2</td>
#       <td>Employ visualisations and narratives to enhance user understanding.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">8.3</td>
#       <td>Organise documentation effectively, indicating a structured approach to information sharing.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <!-- LO9 -->
#     <tr style="font-size: 1.2rem;">
#       <td><strong>LO9</strong></td>
#       <td><strong>Identify and relate the application of data analytics across various domains.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">9.1</td>
#       <td>Explore relevant applications of data analytics in the chosen data domain, indicating a breadth of understanding and curiosity.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">9.2</td>
#       <td>Explain how data analytics and AI can address specific challenges or opportunities.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <!-- LO10 -->
#     <tr style="font-size: 1.2rem;">
#       <td><strong>LO10</strong></td>
#       <td><strong>Develop plans to implement, maintain, update, and evaluate data analytics projects, applying theoretical knowledge to practical scenarios.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">10.1</td>
#       <td>Construct a complete project plan, including implementation, maintenance, updates, and evaluation phases.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">10.2</td>
#       <td>Reflect on the practical challenges and considerations in executing the project.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <!-- LO11 -->
#     <tr style="font-size: 1.2rem;">
#       <td><strong>LO11</strong></td>
#       <td><strong>Demonstrate an ability to adapt to new data analytics tools, technologies, and methodologies, showing a commitment to professional development.</strong></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">11.1</td>
#       <td>Research and experiment with the application of data analytics tools, technologies, and methodologies.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#     <tr>
#       <td style="text-align: end; font-weight: bold;">11.2</td>
#       <td>Evaluate the learning process and how the project has prepared the student for continuous learning and adaptation in the field.</td>
#       <td><input type="checkbox"></td>
#     </tr>
#   </tbody>
# </table>
